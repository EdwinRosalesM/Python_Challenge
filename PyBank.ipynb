# %%
# Importar librerías
import pandas as pd
import csv
import os

# Declaración de Variables
low=0
high=0
tot=0
cuenta=0
name[]=0
chng[]=0
totchng[]=0
prev=0
promchng=0
pnl=0
bgt_csv= os.path.joint("/budget_data.csv")

with open(bgt_csv,'r') as csvfile:
        cvsreader=csv.reader(cvsfile,delimiter=',')
        csv_header= next(cvsreader)
        
        for row in cvsreader:
            cuenta=cuenta+1
            pnl.append(int(row[1]))
            tot=tot+int(row[1])
            name.append(row[0])
            
for x in range(len(pnl)):
    if x==0:
        chng.append(0)
    else:
            chng.append(int(pnl[x])-int(pnl[x-1]))
    
for x in range(len(chng))
        totchng=totchng +int(chng[x])
        if(int(chng[x])>high):
            high=int(chng[x])
            nameI=name[x]
            
        if(int(chng[x])<low):
            low=int(chng[x])
            nameD=name[x]
            
    promchng=round(totchng/float((cont-1)),2)
    
    print("Financial Analysis")
    print("__________________________________")
    print("Total Months "+str(cont))
    print("Total $ "+str(tot))
    print("Average Change "+str(promchng))
    print("Greatest Increase in Profits "+nameI+" "+"($ "+str(high)+")")
    print("Greatest Decrease in Profits "+nameD+" "+"($ "+str(low)+")")
    
    file1=open("pyBankExport.txt","w")
    file1.write("Financial Analysis \n")
    file1.write("__________________ \n")
    file1.write("Total Months "+str(cont)+"\n")
    file1.write("Total: $"+str(tot)+"\n")
    file1.write("Average Change "+str(promchng)+"\n")
    file1.write("Greatest Increase in Profits: "+nameI+" ($ "+str(high)+") \n")
    file1.write("Greatest Decrease in Profits: "+nameD+" ($ "+str(low)+") \n")
    file1.close()
